# %%
import os
os.getcwd()
# Out:
# '/Users/dhanushayerubandi/Downloads'

# %%
import pandas as pd
from io import StringIO
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("cars_engage_2022.csv", index_col=[0])

# %%
df.head(5)
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
df.tail(5)
# Out:
#             Make    Model        Variant Ex-Showroom_Price Displacement  \
# 1271       Honda     City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda     City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda     City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda     City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi  Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 1271        4.0                  4.0  FWD (Front Wheel Drive)
# 1272        4.0                  4.0  FWD (Front Wheel Drive)
# 1273        4.0                  4.0  FWD (Front Wheel Drive)
# 1274        4.0                  4.0  FWD (Front Wheel Drive)
# 1275        4.0                  4.0    AWD (All Wheel Drive)
#
#      Cylinder_Configuration Emission_Norm  ... Leather_Wrapped_Steering  \
# 1271                In-line         BS IV  ...                      Yes
# ...

# %%
df[['Leather_Wrapped_Steering', 'Paddle_Shifters', 'Rain_Sensing_Wipers', 'Bluetooth', 'Cruise_Control', 'Distance_to_Empty', 'Multifunction_Display', 'Engine_Immobilizer', 'ABS_(Anti-lock_Braking_System)', 'EBD_(Electronic_Brake-force_Distribution)', 'Fasten_Seat_Belt_Warning', 'Gear_Shift_Reminder', 'USB_Compatibility', 'Average_Speed', 'Cooled_Glove_Box', 'iPod_Compatibility', 'Turbocharger', 'ISOFIX_(Child-Seat_Mount)', 'FM_Radio', 'ASR_/_Traction_Control', 'Automatic_Headlamps', 'ESP_(Electronic_Stability_Program)']] = df[['Leather_Wrapped_Steering', 'Paddle_Shifters', 'Rain_Sensing_Wipers', 'Bluetooth', 'Cruise_Control', 'Distance_to_Empty', 'Multifunction_Display', 'Engine_Immobilizer', 'ABS_(Anti-lock_Braking_System)', 'EBD_(Electronic_Brake-force_Distribution)', 'Fasten_Seat_Belt_Warning', 'Gear_Shift_Reminder', 'USB_Compatibility', 'Average_Speed', 'Cooled_Glove_Box', 'iPod_Compatibility', 'Turbocharger', 'ISOFIX_(Child-Seat_Mount)', 'FM_Radio', 'ASR_/_Traction_Control', 'Automatic_Headlamps', 'ESP_(Electronic_Stability_Program)']].fillna('No')

# %%
df['Number_of_Airbags'] = df['Number_of_Airbags'].fillna(0)

# %%
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
percent_missing = df.isnull().sum() * 100/ len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
print(missing_value_df)
# Out:
#                          column_name  percent_missing
# Make                            Make         5.877743
# Model                          Model         0.000000
# Variant                      Variant         0.000000
# Ex-Showroom_Price  Ex-Showroom_Price         0.000000
# Displacement            Displacement         0.940439
# ...                              ...              ...
# USB_Ports                  USB_Ports        97.727273
# Heads-Up_Display    Heads-Up_Display        96.003135
# Welcome_Lights        Welcome_Lights        94.592476
# Battery                      Battery        98.981191
# Electric_Range        Electric_Range        98.667712
#
# [140 rows x 2 columns]

# %%
percent_missing.plot(x='column_name', y = 'percent_missing',kind='barh', stacked=False,
        title='Percentage of missing values',figsize = (20,50))
plt.savefig('Percentage of missing values.png')
# Out:
# <AxesSubplot:title={'center':'Percentage of missing values'}>

# %%
missing_value_df.loc[missing_value_df['percent_missing']<70.0,:]
# Out:
#                                        column_name  percent_missing
# Make                                          Make         5.877743
# Model                                        Model         0.000000
# Variant                                    Variant         0.000000
# Ex-Showroom_Price                Ex-Showroom_Price         0.000000
# Displacement                          Displacement         1.018809
# ...                                            ...              ...
# Paddle_Shifters                    Paddle_Shifters         0.000000
# Leather_Wrapped_Steering  Leather_Wrapped_Steering         0.000000
# Automatic_Headlamps            Automatic_Headlamps         0.000000
# ASR_/_Traction_Control      ASR_/_Traction_Control         0.000000
# Cruise_Control                      Cruise_Control         0.000000
#
# [116 rows x 2 columns]

# %%
missing_value_df.loc[missing_value_df['percent_missing']>70.0,:]
# Out:
#                                                                  column_name  \
# ARAI_Certified_Mileage_for_CNG                ARAI_Certified_Mileage_for_CNG
# 3_Point_Seat-Belt_in_Middle_Rear_Seat  3_Point_Seat-Belt_in_Middle_Rear_Seat
# Ambient_Lightning                                          Ambient_Lightning
# Cargo/Boot_Lights                                          Cargo/Boot_Lights
# Drive_Modes                                                      Drive_Modes
# High_Speed_Alert_System                              High_Speed_Alert_System
# Lane_Watch_Camera/_Side_Mirror_Camera  Lane_Watch_Camera/_Side_Mirror_Camera
# Passenger_Side_Seat-Belt_Reminder          Passenger_Side_Seat-Belt_Reminder
# Voice_Recognition                                          Voice_Recognition
# Walk_Away_Auto_Car_Lock                              Walk_Away_Auto_Car_Lock
# Compression_Ratio                                          Compression_Ratio
# ...

# %%
df.drop(['ARAI_Certified_Mileage_for_CNG', '3_Point_Seat-Belt_in_Middle_Rear_Seat', 'Ambient_Lightning', 'Cargo/Boot_Lights', 'Drive_Modes', 'High_Speed_Alert_System', 'Lane_Watch_Camera/_Side_Mirror_Camera', 'Passenger_Side_Seat-Belt_Reminder', 'Voice_Recognition', 'Walk_Away_Auto_Car_Lock', 'Compression_Ratio', 'Other_Specs', 'Other_Specs', 'Android_Auto', 'Apple_CarPlay', 'Tyre_Pressure_Monitoring_System', 'Recommended_Tyre_Pressure', 'Heated_Seats', 'Engine_Type', 'USB_Ports', 'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'], axis = 1, inplace = True)

# %%
df.dtypes
# Out:
# Make                        object
# Model                       object
# Variant                     object
# Ex-Showroom_Price           object
# Displacement                object
#                              ...
# Paddle_Shifters             object
# Leather_Wrapped_Steering    object
# Automatic_Headlamps         object
# ASR_/_Traction_Control      object
# Cruise_Control              object
# Length: 117, dtype: object

# %%
df['Height'] = df['Height'].astype(str).str.replace(' mm','',regex=False).astype(float)
df['Length'] = df['Length'].astype(str).str.replace(' mm','',regex=False).astype(float)
df['Width'] = df['Width'].astype(str).str.replace(' mm','',regex=False).astype(float)
df['Ground_Clearance'] = df['Ground_Clearance'].astype(str).str.replace(' mm','',regex=False).astype(float)
df['Wheelbase'] = df['Wheelbase'].astype(str).str.replace(' mm','',regex=False).astype(float)
df['Boot_Space'] = df['Height'].astype(str).str.replace(' mm','',regex=False).astype(float)
df['Boot_Space'] = df['Boot_Space'].astype(str).str.replace(' litres','',regex=False).astype(float)
df['Fuel_Tank_Capacity'] = df['Fuel_Tank_Capacity'].astype(str).str.replace(' litres','',regex=False).astype(float)

# %%
df['Ex-Showroom_Price']=df['Ex-Showroom_Price'].astype(str).str.replace('Rs. ','',regex=False)
df['Ex-Showroom_Price']=df['Ex-Showroom_Price'].astype(str).str.replace(',','',regex=False)
df['Ex-Showroom_Price']=df['Ex-Showroom_Price'].astype(float)
df['price']=df['Ex-Showroom_Price']
df.drop(columns='Ex-Showroom_Price', inplace= True)
df.price = df.price.astype(float)
df.price
# Out:
# 0        292667.0
# 1        236447.0
# 2        296661.0
# 3        334768.0
# 4        272223.0
#           ...
# 1271    1302000.0
# 1272    1421000.0
# 1273    1431000.0
# 1274    1201000.0
# 1275    6862560.0
# Name: price, Length: 1276, dtype: float64

# %%
print(df)
# Out:
#             Make      Model        Variant Displacement  Cylinders  \
# 0           Tata  Nano Genx             Xt       624 cc        2.0
# 1           Tata  Nano Genx             Xe       624 cc        2.0
# 2           Tata  Nano Genx        Emax Xm       624 cc        2.0
# 3           Tata  Nano Genx            Xta       624 cc        2.0
# 4           Tata  Nano Genx             Xm       624 cc        2.0
# ...          ...        ...            ...          ...        ...
# 1271       Honda       City   Vx Mt Diesel      1498 cc        4.0
# 1272       Honda       City   Zx Mt Diesel      1498 cc        4.0
# 1273       Honda       City  Zx Cvt Petrol      1497 cc        4.0
# 1274       Honda       City   V Cvt Petrol      1497 cc        4.0
# 1275  Mitsubishi    Montero         3.2 At      3200 cc        4.0
#
#       Valves_Per_Cylinder               Drivetrain Cylinder_Configuration  \
# 0                     2.0   RWD (Rear Wheel Drive)                In-line
# ...

# %%
sns.histplot(df.Boot_Space,bins=20)
plt.savefig('Bootspace.png')
# Out:
# <AxesSubplot:xlabel='Boot_Space', ylabel='Count'>

# %%
sns.histplot(df.Wheelbase,bins=10)
plt.savefig('wheelbase.png')
# Out:
# <AxesSubplot:xlabel='Wheelbase', ylabel='Count'>

# %%
sns.boxplot(x='Fuel_Type', y='price', data=df)
plt.ylim(0,20000000)
plt.savefig('fuel_type.png')
# Out:
# (0.0, 20000000.0)

# %%
sns.boxplot(x='Bluetooth', y='price', data=df)
plt.ylim(0,20000000)
plt.savefig('bluetooth.png')
# Out:
# (0.0, 20000000.0)

# %%
sns.boxplot(x='Type', y='price', data=df)
plt.ylim(0,20000000)
plt.savefig('type.png')
# Out:
# (0.0, 20000000.0)

# %%
sns.boxplot(y = df["Body_Type"], x = df["price"])
plt.xlim(0,220000000)
plt.savefig('body_type.png')
# Out:
# (0.0, 220000000.0)

# %%
df2 = df[['Make','Body_Type']]
df3 = df2.groupby(['Make','Body_Type'],as_index=False)['Make','Body_Type'].value_counts()
pivot = pd.pivot_table(data = df3, index = ['Make'], columns = ['Body_Type'], values = 'count')
pivot = pivot.reset_index(drop=False)
pivot

pivot.plot(x='Make', kind='bar', stacked=True,
        title='Stacked Bar Graph by Make and Body type', figsize = (10,10))
plt.savefig('make_body_type.png')
# Out:
# /var/folders/y5/6pkyy21d0b38t7hf6mhw9x7h0000gn/T/ipykernel_3199/838742743.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3 = df2.groupby(['Make','Body_Type'],as_index=False)['Make','Body_Type'].value_counts()
# <AxesSubplot:title={'center':'Stacked Bar Graph by Make and Body type'}, xlabel='Make'>

# %%
df4 = df[['Number_of_Airbags','price']]
df4 = df4.groupby(['Number_of_Airbags'],as_index = False)['price'].mean()
df4
df4.plot(x = 'Number_of_Airbags', y = 'price')
plt.savefig('airbags.png')
# Out:
# <AxesSubplot:xlabel='Number_of_Airbags'>

# %%
df5 = df[['Body_Type','price']]
df5 = df5.groupby(['Body_Type'],as_index=False)['price'].mean()
df5.plot(x = 'Body_Type', y ='price', kind = 'bar')
plt.savefig('Price_bodytype.png')
# Out:
# <AxesSubplot:xlabel='Body_Type'>

# %%
df6 = df[['Make','price']]
df6 = df6.groupby(['Make'],as_index=False)['price'].mean()
df6.plot(x = 'Make', y ='price', kind = 'bar')
plt.savefig('make_price.png')
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
df7 = df[['Make','Fuel_Type']]
df8 = df7.groupby(['Make','Fuel_Type'],as_index=False)['Make','Fuel_Type'].value_counts()
pivot2 = pd.pivot_table(data = df8, index = ['Make'], columns = ['Fuel_Type'], values = 'count')
pivot2 = pivot2.reset_index(drop=False)
pivot2

pivot2.plot(x='Make', kind='bar', stacked=True,
        title='Stacked Bar Graph by Make and Body type', figsize = (10,10))
plt.savefig('make_fueltype.png')

# %%
Features_df = df[['Leather_Wrapped_Steering', 'Paddle_Shifters', 'Rain_Sensing_Wipers', 'Bluetooth', 'Cruise_Control', 'Distance_to_Empty', 'Multifunction_Display', 'Engine_Immobilizer', 'ABS_(Anti-lock_Braking_System)', 'EBD_(Electronic_Brake-force_Distribution)', 'Fasten_Seat_Belt_Warning', 'Gear_Shift_Reminder', 'USB_Compatibility', 'Average_Speed', 'Cooled_Glove_Box', 'iPod_Compatibility', 'Turbocharger', 'ISOFIX_(Child-Seat_Mount)', 'FM_Radio', 'ASR_/_Traction_Control', 'Automatic_Headlamps', 'ESP_(Electronic_Stability_Program)']] = df[['Leather_Wrapped_Steering', 'Paddle_Shifters', 'Rain_Sensing_Wipers', 'Bluetooth', 'Cruise_Control', 'Distance_to_Empty', 'Multifunction_Display', 'Engine_Immobilizer', 'ABS_(Anti-lock_Braking_System)', 'EBD_(Electronic_Brake-force_Distribution)', 'Fasten_Seat_Belt_Warning', 'Gear_Shift_Reminder', 'USB_Compatibility', 'Average_Speed', 'Cooled_Glove_Box', 'iPod_Compatibility', 'Turbocharger', 'ISOFIX_(Child-Seat_Mount)', 'FM_Radio', 'ASR_/_Traction_Control', 'Automatic_Headlamps', 'ESP_(Electronic_Stability_Program)']]
Features_df['price'] = df['price']
Features_df

Features_df.replace({"Yes": 1, "No": 0}, inplace=True)
Features_df['feature_count'] = Features_df.iloc[:, 1:22].sum(axis=1)
Features_df
# Out:
#       Leather_Wrapped_Steering  Paddle_Shifters  Rain_Sensing_Wipers  \
# 0                            0                0                    0
# 1                            0                0                    0
# 2                            0                0                    0
# 3                            0                0                    0
# 4                            0                0                    0
# ...                        ...              ...                  ...
# 1271                         1                0                    0
# 1272                         1                0                    1
# 1273                         1                1                    0
# 1274                         0                1                    0
# 1275                         1                0                    1
#
#       Bluetooth  Cruise_Control  Distance_to_Empty  Multifunction_Display  \
# ...

# %%
Features_df = Features_df[['feature_count','price']]
Features_df = Features_df.groupby(['feature_count'],as_index = False)['price'].mean()
Features_df
Features_df.plot(x = 'feature_count', y = 'price')
plt.savefig('feature_count.png')
